# %% [markdown]
# <a href="https://colab.research.google.com/github/iterat1on/class/blob/main/%EA%B3%B5%EB%AA%A8%EC%A0%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
from tqdm import tqdm
import time

# %%
df = pd.read_csv("/content/drive/MyDrive/서울시_우리마을가게_상권분석서비스(신_상권_추정매출)_2021년.csv", encoding="cp949")

# %%
df.head()
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드 상권_코드_명 서비스_업종_코드  \
# 0     2021         1        A       골목상권  2110001  이북5도청사  CS100001
# 1     2021         1        A       골목상권  2110001  이북5도청사  CS100008
# 2     2021         1        A       골목상권  2110001  이북5도청사  CS100009
# 3     2021         1        A       골목상권  2110001  이북5도청사  CS100010
# 4     2021         1        A       골목상권  2110001  이북5도청사  CS200001
#
#   서비스_업종_코드_명  분기당_매출_금액  분기당_매출_건수  ...  시간대_건수~24_매출_건수  남성_매출_건수  여성_매출_건수  \
# 0       한식음식점  626851391      25502  ...              157     15667      7253
# 1       분식전문점  122957138      12039  ...                0      6679      4293
# 2     호프-간이주점    5093349        177  ...                9       124        36
# 3       커피-음료   13507733       1359  ...                8       356       881
# 4      일반교습학원   37551380        128  ...                0        56        72
#
#    연령대_10_매출_건수  연령대_20_매출_건수  연령대_30_매출_건수  연령대_40_매출_건수  연령대_50_매출_건수  \
# ...

# %%
서울대 = ["샤로수길", "서울대입구", "서울대입구 8번", "관악소방서(문영여고)", "낙성대역 5번", "낙성대역 1번", "녹두거리(대학동)"]
중앙대 = ["상도역 1번", "상도역 5번", "중앙대학교", "흑리단길", "상도역 2번"]
숭실대 = ["숭실대입구 1번", "숭실대입구 4번", "상도1동 주민센터"]
연세대 = ["연희초등학교", "연희파출소", "서대문우체국", "서대문소방서", "경의중앙 신촌역","연희세브란스병원", "봉원사", "신촌역 6번", "대흥동주민센터", "신촌역(신촌역, 신촌로터리)","연희동", "이화여대(이대역, 이대)"]
이화여대 = ["경의중앙 신촌역", "연희세브란스병원", "봉원사", "신촌역 6번", "대흥동주민센터", "이대역 5번", "신촌역(신촌역, 신촌로터리)", "이화여대(이대역, 이대)"]
서강대 = ["서강대역 1번", "신촌역 6번", "서강대학교", "대흥역 2번", "대흥역 3번", "양원초등학교", "신촌역(신촌역, 신촌로터리)"]
홍익대 = ["상수역 4번", "연트럴파크", "상수역 3번", "홍대입구역 3번", "홍익대", "경의선 책거리", "홍대땡땡거리", "합정역", "서교동(홍대)", "홍대입구역(홍대)", "연남동(홍대)", "상수역(홍대)"]
국민대 = ["국민대학교앞", "북한산보국문역 2번"]
숙명여대 = ["남영역 1번", "숙대입구", "숙대입구역(남영역, 남영동)"]
동국대 = ["충무초등학교", "장충동족발거리(남소영길)", "충무로역"]
경희대 = ["경희대삼거리", "경희대후문", "청량초등학교", "회기역 1번" , "경희대학교(경희대)", "회기역"]
외대 = ["외대앞역1번", "외대앞역 2번", "청량초등학교", "경희대후문", "회기역 1번", "회기역" ]
시립대 = ["시립대앞사거리", "서울시립대", "텃골근린공원", "전곡마을마당공원", "전농중학교", "청량리역(청량리)"]
고려대 = ["고려대역 4번", "고려대역 6번", "고대앞사거리", "종암중학교", "종암초등학교", "용두희망어린이공원", "안암역 2번", "안암역 3번", "안암역"]

# %%
college_list = ["서울대", "중앙대", "숭실대", "연세대", "이화여대", "서강대", "홍익대", "국민대", "숙명여대", "동국대", "경희대", "외대", "시립대", "고려대"]

# %%
col_dict = {}
for colname in college_list :
  col_dict.update(dict.fromkeys(globals()[colname], colname))

# %%
col_dict
# Out:
# {'샤로수길': '서울대',
#  '서울대입구': '서울대',
#  '서울대입구 8번': '서울대',
#  '관악소방서(문영여고)': '서울대',
#  '낙성대역 5번': '서울대',
#  '낙성대역 1번': '서울대',
#  '녹두거리(대학동)': '서울대',
#  '상도역 1번': '중앙대',
#  '상도역 5번': '중앙대',
#  '중앙대학교': '중앙대',
#  '흑리단길': '중앙대',
#  '상도역 2번': '중앙대',
#  '숭실대입구 1번': '숭실대',
#  '숭실대입구 4번': '숭실대',
#  '상도1동 주민센터': '숭실대',
#  '연희초등학교': '연세대',
#  '연희파출소': '연세대',
#  '서대문우체국': '연세대',
#  '서대문소방서': '연세대',
#  '경의중앙 신촌역': '이화여대',
#  '연희세브란스병원': '이화여대',
#  '봉원사': '이화여대',
#  '신촌역 6번': '서강대',
#  '대흥동주민센터': '이화여대',
#  '신촌역(신촌역, 신촌로터리)': '서강대',
#  '연희동': '연세대',
#  '이화여대(이대역, 이대)': '이화여대',
#  '이대역 5번': '이화여대',
#  '서강대역 1번': '서강대',
#  '서강대학교': '서강대',
#  '대흥역 2번': '서강대',
#  '대흥역 3번': '서강대',
#  '양원초등학교': '서강대',
#  '상수역 4번': '홍익대',
#  '연트럴파크': '홍익대',
#  '상수역 3번': '홍익대',
#  '홍대입구역 3번': '홍익대',
#  '홍익대': '홍익대',
#  '경의선 책거리': '홍익대',
#  '홍대땡땡거리': '홍익대',
#  '합정역': '홍익대',
#  '서교동(홍대)': '홍익대',
#  '홍대입구역(홍대)': '홍익대',
#  '연남동(홍대)': '홍익대',
#  '상수역(홍대)': '홍익대',
#  '국민대학교앞': '국민대',
#  '북한산보국문역 2번': '국민대',
#  '남영역 1번': '숙명여대',
# ...

# %%
for index,row in tqdm(df.iterrows(), total = df.shape[0]):
  try:
    df.loc[index,'대학'] = col_dict[df.loc[index, ["상권_코드_명"]]d[0]]
  except KeyError:
    pass
# Out:
# 100%|██████████| 140830/140830 [01:56<00:00, 1205.02it/s]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140830 entries, 0 to 140829
# Data columns (total 81 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   기준_년_코드          140830 non-null  int64
#  1   기준_분기_코드         140830 non-null  int64
#  2   상권_구분_코드         140830 non-null  object
#  3   상권_구분_코드_명       140830 non-null  object
#  4   상권_코드            140830 non-null  int64
#  5   상권_코드_명          140830 non-null  object
#  6   서비스_업종_코드        140830 non-null  object
#  7   서비스_업종_코드_명      140830 non-null  object
#  8   분기당_매출_금액        140830 non-null  int64
#  9   분기당_매출_건수        140830 non-null  int64
#  10  주중_매출_비율         140830 non-null  int64
#  11  주말_매출_비율         140830 non-null  int64
#  12  월요일_매출_비율        140830 non-null  int64
#  13  화요일_매출_비율        140830 non-null  int64
#  14  수요일_매출_비율        140830 non-null  int64
#  15  목요일_매출_비율        140830 non-null  int64
# ...

# %%
df[df["대학"] == "서울대"]
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 16881      2021         1        A       골목상권  2110893  관악소방서(문영여고)  CS100001
# 16882      2021         1        A       골목상권  2110893  관악소방서(문영여고)  CS100010
# 16883      2021         1        A       골목상권  2110893  관악소방서(문영여고)  CS200036
# 16884      2021         1        A       골목상권  2110893  관악소방서(문영여고)  CS300001
# 16886      2021         1        A       골목상권  2110895         샤로수길  CS100001
# ...         ...       ...      ...        ...      ...          ...       ...
# 131273     2021         4        D       발달상권  2120158    녹두거리(대학동)  CS300018
# 131274     2021         4        D       발달상권  2120158    녹두거리(대학동)  CS300020
# 131275     2021         4        D       발달상권  2120158    녹두거리(대학동)  CS300021
# 131276     2021         4        D       발달상권  2120158    녹두거리(대학동)  CS300028
# 131277     2021         4        D       발달상권  2120158    녹두거리(대학동)  CS300035
#
# ...

# %%
df_filtered = df.dropna(subset=['대학'])

# %%
df_filtered
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드    상권_코드_명 서비스_업종_코드  \
# 505        2021         1        A       골목상권  2110043     충무초등학교  CS100001
# 506        2021         1        A       골목상권  2110043     충무초등학교  CS100002
# 507        2021         1        A       골목상권  2110043     충무초등학교  CS100005
# 508        2021         1        A       골목상권  2110043     충무초등학교  CS100008
# 509        2021         1        A       골목상권  2110043     충무초등학교  CS100009
# ...         ...       ...      ...        ...      ...        ...       ...
# 131273     2021         4        D       발달상권  2120158  녹두거리(대학동)  CS300018
# 131274     2021         4        D       발달상권  2120158  녹두거리(대학동)  CS300020
# 131275     2021         4        D       발달상권  2120158  녹두거리(대학동)  CS300021
# 131276     2021         4        D       발달상권  2120158  녹두거리(대학동)  CS300028
# 131277     2021         4        D       발달상권  2120158  녹두거리(대학동)  CS300035
#
# ...

# %%
 df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5983 entries, 505 to 131277
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   기준_년_코드          5983 non-null   int64
#  1   기준_분기_코드         5983 non-null   int64
#  2   상권_구분_코드         5983 non-null   object
#  3   상권_구분_코드_명       5983 non-null   object
#  4   상권_코드            5983 non-null   int64
#  5   상권_코드_명          5983 non-null   object
#  6   서비스_업종_코드        5983 non-null   object
#  7   서비스_업종_코드_명      5983 non-null   object
#  8   분기당_매출_금액        5983 non-null   int64
#  9   분기당_매출_건수        5983 non-null   int64
#  10  주중_매출_비율         5983 non-null   int64
#  11  주말_매출_비율         5983 non-null   int64
#  12  월요일_매출_비율        5983 non-null   int64
#  13  화요일_매출_비율        5983 non-null   int64
#  14  수요일_매출_비율        5983 non-null   int64
#  15  목요일_매출_비율        5983 non-null   int64
#  16  금요일_매출_비율        5983 non-null   int64
# ...

# %%
df_filtered["대학"].value_counts()
# Out:
# 홍익대     1200
# 서강대      668
# 고려대      665
# 시립대      517
# 중앙대      460
# 연세대      427
# 이화여대     412
# 숙명여대     365
# 외대       347
# 동국대      313
# 서울대      275
# 경희대      213
# 국민대      121
# Name: 대학, dtype: int64
